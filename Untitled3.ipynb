# %% [markdown]
# <a href="https://colab.research.google.com/github/wilkeamerico/git-aula-1/blob/main/Untitled3.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
leitura_ruidosa = 24.897654321
# round(valor, numero_de_casas)
leitura_tratada = round(leitura_ruidosa, 1)
print(f"Bruto: {leitura_ruidosa}")
print(f"Tratado: {leitura_tratada}")
# Out:
# Bruto: 24.897654321
# Tratado: 24.9
