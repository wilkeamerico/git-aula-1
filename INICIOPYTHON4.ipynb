# %% [markdown]
# <a href="https://colab.research.google.com/github/wilkeamerico/git-aula-1/blob/main/INICIOPYTHON4.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
tensao = 3.333333
id_device = 12

print(f"TENSÃO: {tensao:.2f}V no ID: {id_device}")

#----------------------------------------------------------------------

print("tensão: " + str(tensao) + "V no ID: " + str(id_device))

#----------------------------------------------------------------------
# Exemplo: Simulando um ajuste de Setpoint de temperatura

# 1. O programa pausa e espera o usuário digitar e apertar Enter
dado_digitado = input("DIGITE TEMPERATURA DESEJADA: ")
# 2. Convertemos imediatamente para float para poder usar em cálculos
setpoint = float(dado_digitado)

print(f"SISTEMA CONFIGURADO PARA: {setpoint:.1f}°C")
print(f"TIPO DE VARIAVEL: {type(setpoint)}")
# Out:
# TENSÃO: 3.33V no ID: 12
# tensão: 3.333333V no ID: 12
# DIGITE TEMPERATURA DESEJADA: 33
# SISTEMA CONFIGURADO PARA: 33.0°C
# TIPO DE VARIAVEL: <class 'float'>
