# %% [markdown]
# <a href="https://colab.research.google.com/github/wilkeamerico/git-aula-1/blob/main/INICIOPYTHON2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# Declarando variáveis
placa = "ESP32"
  # O Python entende as aspas como texto (str)
versao = 1.025
  # O ponto define que é decimal (float)
pinos = 30
  # Número puro é inteiro (int)
ligado = True
  # Palavra reservada para estado lógico (bool)
# Verificando o tipo de CADA variável
print(f"Variável 'placa' é do tipo: {type(placa)}")
print(f"Variável 'versao' é do tipo: {type(versao)}")
print(f"Variável 'pinos' é do tipo: {type(pinos)}")
print(f"Variável 'ligado' é do tipo: {type(ligado)}")
# Out:
# Variável 'placa' é do tipo: <class 'str'>
# Variável 'versao' é do tipo: <class 'float'>
# Variável 'pinos' é do tipo: <class 'int'>
# Variável 'ligado' é do tipo: <class 'bool'>
