# %% [markdown]
# <a href="https://colab.research.google.com/github/wilkeamerico/git-aula-1/blob/main/INICIOPYTHON1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
print("Olá, IoT! O ambiente está configurado!")
# Out:
# Olá, IoT! O ambiente está configurado!
