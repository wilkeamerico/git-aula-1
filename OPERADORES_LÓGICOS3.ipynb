# %% [markdown]
# <a href="https://colab.research.google.com/github/wilkeamerico/git-aula-1/blob/main/OPERADORES_L%C3%93GICOS3.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
sistema_ligado = False
conexao_wifi = True

print("--- Iniciando Diagnóstico ---")

if sistema_ligado:
  print("Sistema Operante.")
  # Este if só é testado porque o sistema está ligado
  if conexao_wifi:
    print("Enviando dados para nuvem...")
  else:
    print("Erro: Sem conexão! Salvando no cartão SD...")
else:
  print("Sistema Desligado. Nada a fazer.")
# Out:
# --- Iniciando Diagnóstico ---
# Sistema Desligado. Nada a fazer.
