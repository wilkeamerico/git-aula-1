# %% [markdown]
# <a href="https://colab.research.google.com/github/wilkeamerico/git-aula-1/blob/main/Aritmetica.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
a = 10
b = 3
print(f"Soma (+): {a + b}")
print(f"Subtração (-): {a - b}")
print(f"Multiplicação (*): {a * b}")
print(f"Divisão Real (/): {a / b}") # Resultado sempre float
print(f"Potência (**): {a ** b}") # 10 elevado a 3
# Out:
# Soma (+): 13
# Subtração (-): 7
# Multiplicação (*): 30
# Divisão Real (/): 3.3333333333333335
# Potência (**): 1000
